# %% [markdown]
# # Setup Assets Notebook
#
# Use this notebook once to prepare local assets for training:
# 1. Download product images into `data/images/`.
# 2. Download the FastText model file (`cc.en.300.bin`).
#
# Run cells top-to-bottom from the repository root (`ProjectDeepLearning/`).

# %%
import os
import pandas as pd 
import numpy as np
from data.utils import download_images

data = pd.read_csv('./data/data.csv')
download_images(data['image_link'], './data/images')

# %% [markdown]
# ## Download fasttext model

# %%
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')  # English
ft = fasttext.load_model('cc.en.300.bin')
# Out:
# ...
#  (100.00%) [==================================================>]                                                 ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]
# ...

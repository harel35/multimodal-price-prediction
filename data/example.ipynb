# %% [markdown]
# # Dataset Inspection Notebook
#
# This notebook is a lightweight sandbox for inspecting `data/data.csv`, validating image paths, and trying small preprocessing snippets before running `main.py`.
#
# It is exploratory only; training/evaluation should be run from CLI entry points.

# %%
import os
import pandas as pd 
import numpy as np

# %% [markdown]
# ##  Read Dataset

# %%
DATASET_FOLDER = './'
data = pd.read_csv(os.path.join(DATASET_FOLDER, 'data.csv'))

# %%
from utils import download_images
download_images(data['image_link'], './images')

# %%
len(os.listdir('../images'))
